# %%
# Escritura y lectura de archivos en Python

# %%
## Se almacena un texto en una variable.
txt = '''R is a programming language and software environment for statistical computing
and graphics supported by the R Foundation for Statistical Computing.[3] The R language
is widely used among statisticians and data miners for developing statistical software[4]
and data analysis.[5] Polls, surveys of data miners, and studies of scholarly literature
databases show that R's popularity has increased substantially in recent years.[6]
'''

# %%
print(txt)
# Out:
# R is a programming language and software environment for statistical computing
# and graphics supported by the R Foundation for Statistical Computing.[3] The R language
# is widely used among statisticians and data miners for developing statistical software[4]
# and data analysis.[5] Polls, surveys of data miners, and studies of scholarly literature
# databases show that R's popularity has increased substantially in recent years.[6]

# %%
## Se escribe el contenido de `txt` a un archivo en disco
open('wikipedia.txt', 'w').write(txt)
# Out:
# 429

# %%
## abre el archivo, lee todo el contenido del archivo y luego lo cierra.
open('wikipedia.txt', 'r').read()
# Out:
# "R is a programming language and software environment for statistical computing\nand graphics supported by the R Foundation for Statistical Computing.[3] The R language\nis widely used among statisticians and data miners for developing statistical software[4]\nand data analysis.[5] Polls, surveys of data miners, and studies of scholarly literature\ndatabases show that R's popularity has increased substantially in recent years.[6]\n"

# %%
#ESCRITURA SECUENCIAL A UN ARCHIVO
## Se abre el archivo para escritura
f = open('out.1', 'w')

# %%
## impresión de varias lineas en un solo print
print("linea 1", "linea 2", "linea 3", sep='\n', file=f)

# %%
## impresión de una línea por print
print("linea 4", file=f)
print("linea 5", file=f)
print("linea 6", file=f)

# %%
## impresión usando write
f.write('linea 7')
# Out:
# 7

# %%
## cierra el archivo
f.close()

# %%
#LECTURA DE UN ARCHIVO
## contenido del archivo
open('out.1', 'r').read()
# Out:
# 'linea 1\nlinea 2\nlinea 3\nlinea 1\nlinea 2\nlinea 3\nlinea 1\nlinea 2\nlinea 3\nlinea 4\nlinea 5\nlinea 6\nlinea 7'

# %%
## impresión con formato del contenido de un archivo.
print(open('out.1', 'r').read())
# Out:
# linea 1
# linea 2
# linea 3
# linea 1
# linea 2
# linea 3
# linea 1
# linea 2
# linea 3
# linea 4
# linea 5
# linea 6
# linea 7

# %%
## forma alternativa (mas usual)
with open('out.1', 'r') as f:
  print(f.read, end='')
# Out:
# <built-in method read of _io.TextIOWrapper object at 0x7f45e04073a8>
# True

# %%
f.closed
# Out:
# True

# %%
## Otra forma, observe el uso de `list`.
f = open('out.1', 'r')
x = list(f)
f.close()
x  # note que aparece el retorno de carro '\n' al final de cada línea
# Out:
# ['linea 1\n',
#  'linea 2\n',
#  'linea 3\n',
#  'linea 1\n',
#  'linea 2\n',
#  'linea 3\n',
#  'linea 1\n',
#  'linea 2\n',
#  'linea 3\n',
#  'linea 4\n',
#  'linea 5\n',
#  'linea 6\n',
#  'linea 7']

# %%
#Lectura secuencial del contenido de un archivo línea por línea
## Lectura del contenido
## de un archivo línea a línea.
f = open('out.1', 'r')

# %%
## Lee la primera línea.
f.readline()
# Out:
# 'linea 1\n'

# %%
## lee la segunda línea.
f.readline()
# Out:
# 'linea 2\n'

# %%
## lee la tercera línea y así sucesivamente
## hasta alcanzar el final del archivo
f.readline()
# Out:
# 'linea 3\n'

# %%
f.close() # cierra el archivo.

# %%
#Lectura secuencial del contenido de un archivo usando un ciclo for
## abre el archivo
f = open('out.1', 'r')

## se itera sobre cada linea del archivo
## una a la vez
for line in f:
    print(line, end='')
f.close()
# Out:
# linea 1
# linea 2
# linea 3
# linea 1
# linea 2
# linea 3
# linea 1
# linea 2
# linea 3
# linea 4
# linea 5
# linea 6
# linea 7

# %%
# Lectura y escritura de tablas de texto
#El parámetro delimiter permite especificar el caracter delimitador, mientras
#que el parámetro quoting permite especificar los delimitadores para los strings.
## crea la tabla de datos de prueba.
## cada fila es una lista
df = [["index", "name", "value"],
      [1, "A", 3.03],
      [2, "B", 5.14],
      [3, "C", 0.40],
      [4, "D", 1.13],
      [5, "E", 8.25]]
df
# Out:
# [['index', 'name', 'value'],
#  [1, 'A', 3.03],
#  [2, 'B', 5.14],
#  [3, 'C', 0.4],
#  [4, 'D', 1.13],
#  [5, 'E', 8.25]]

# %%
## importa la librería
import csv

# %%
#Archivos delimitados por espacios
## escribe el archivo en forma de tabla de texto
with open('files/data.txt', 'w') as f:             # abre el archivo para escritura
    x = csv.writer(f,                              # crea el objeto x
                   delimiter=' ',                  # delimitado por ' '
                   quoting=csv.QUOTE_NONNUMERIC)   # sin " " para los strings
    for r in df:
        x.writerow(r)

# %%
## verifica el archivo creado
print(open('files/data.txt', 'r').read())
# Out:
# "index" "name" "value"
# 1 "A" 3.03
# 2 "B" 5.14
# 3 "C" 0.4
# 4 "D" 1.13
# 5 "E" 8.25

# %%
## Lee el archivo como una tabla de texto
with open('files/data.txt', 'r') as f:
    x = csv.reader(f,
                    delimiter=' ',
                    quoting=csv.QUOTE_NONNUMERIC)

## verifica el archivo creado
open('files/data.txt', 'r').read()
# Out:
# '"index" "name" "value"\n1 "A" 3.03\n2 "B" 5.14\n3 "C" 0.4\n4 "D" 1.13\n5 "E" 8.25\n'

# %%
print(open('files/data.txt', 'r').read())
# Out:
# "index" "name" "value"
# 1 "A" 3.03
# 2 "B" 5.14
# 3 "C" 0.4
# 4 "D" 1.13
# 5 "E" 8.25

# %%
#Archivos en formato JSON
## importa la libreria
import json

# %%
## convierte los datos en string
json.dumps(df)
# Out:
# '[["index", "name", "value"], [1, "A", 3.03], [2, "B", 5.14], [3, "C", 0.4], [4, "D", 1.13], [5, "E", 8.25]]'

# %%
## mismo caso anterior pero con impresion 'bonita'
json.dumps(df,
           sort_keys = True,
           indent = 4)
# Out:
# '[\n    [\n        "index",\n        "name",\n        "value"\n    ],\n    [\n        1,\n        "A",\n        3.03\n    ],\n    [\n        2,\n        "B",\n        5.14\n    ],\n    [\n        3,\n        "C",\n        0.4\n    ],\n    [\n        4,\n        "D",\n        1.13\n    ],\n    [\n        5,\n        "E",\n        8.25\n    ]\n]'

# %%
y = json.dumps(df,
               sort_keys = True,
               indent = 4)
print(y)
# Out:
# [
#     [
#         "index",
#         "name",
#         "value"
#     ],
#     [
#         1,
#         "A",
#         3.03
#     ],
#     [
#         2,
#         "B",
#         5.14
#     ],
#     [
#         3,
#         "C",
#         0.4
#     ],
#     [
#         4,
#         "D",
#         1.13
#     ],
#     [
#         5,
#         "E",
#         8.25
#     ]
# ]

# %%
## convierte el string en datos
json.loads(y)
# Out:
# [['index', 'name', 'value'],
#  [1, 'A', 3.03],
#  [2, 'B', 5.14],
#  [3, 'C', 0.4],
#  [4, 'D', 1.13],
#  [5, 'E', 8.25]]

# %%
  ## convierte los datos en string y
## los guarda en un archivo
with open('files/data.json', 'w') as f:
    json.dump(obj = df,   # datos
              fp = f)     # archivo

# %%
open('content/data.csv', 'r').read()

# %%
## recupera los datos desde el archivo
with open('files/data.json', 'r') as f:
    x = json.load(fp = f)
x
# Out:
# [['index', 'name', 'value'],
#  [1, 'A', 3.03],
#  [2, 'B', 5.14],
#  [3, 'C', 0.4],
#  [4, 'D', 1.13],
#  [5, 'E', 8.25]]

# %%
#Formato binario nativo de Python
## carga la librería
import pickle

# %%
## salva el objeto en el disco
with open('files/data.pickle', 'wb') as f:
    pickle.dump(obj = df, file = f)

# %%
## borra la variable x
del df

# %%
whos
# Out:
# Variable   Type              Data/Info
# --------------------------------------
# csv        module            <module 'csv' from '/usr/lib/python3.6/csv.py'>
# f          BufferedWriter    <_io.BufferedWriter name='files/data.pickle'>
# json       module            <module 'json' from '/usr<...>hon3.6/json/__init__.py'>
# line       str               linea 7
# pickle     module            <module 'pickle' from '/u<...>lib/python3.6/pickle.py'>
# r          list              n=3
# txt        str               R is a programming langua<...>lly in recent years.[6]\n
# x          list              n=6
# y          str               [\n    [\n        "index"<...>,\n        8.25\n    ]\n]

# %%
## recupera el objeto del disco
with open('files/data.pickle', 'rb') as f:
    df = pickle.load(f)

print(df)
# Out:
# [['index', 'name', 'value'], [1, 'A', 3.03], [2, 'B', 5.14], [3, 'C', 0.4], [4, 'D', 1.13], [5, 'E', 8.25]]

# %%
#TALLER: WORDCOUNT EN PYTHON

# %%
## 
## Se crea el directorio wordcount en la carpeta actual de trabajo
## y se escriben tres archivos en ella.
##
# !mkdir -p wordcount/

# %%
# %%writefile wordcount/text0.txt
# Analytics is the discovery, interpretation, and communication of meaningful patterns
# in data. Especially valuable in areas rich with recorded information, analytics relies
# on the simultaneous application of statistics, computer programming and operations research
# to quantify performance.
#
# Organizations may apply analytics to business data to describe, predict, and improve business
# performance. Specifically, areas within analytics include predictive analytics, prescriptive
# analytics, enterprise decision management, descriptive analytics, cognitive analytics, Big
# Data Analytics, retail analytics, store assortment and stock-keeping unit optimization,
# marketing optimization and marketing mix modeling, web analytics, call analytics, speech
# analytics, sales force sizing and optimization, price and promotion modeling, predictive
# science, credit risk analysis, and fraud analytics. Since analytics can require extensive
# computation (see big data), the algorithms and software used for analytics harness the most
# current methods in computer science, statistics, and mathematics.
# Out:
# Overwriting wordcount/text0.txt

# %%
# %%writefile wordcount/text1.txt
# The field of data analysis. Analytics often involves studying past historical data to
# research potential trends, to analyze the effects of certain decisions or events, or to
# evaluate the performance of a given tool or scenario. The goal of analytics is to improve
# the business by gaining knowledge which can be used to make improvements or changes.
# Out:
# Overwriting wordcount/text1.txt

# %%
# %%writefile wordcount/text2.txt
# Data analytics (DA) is the process of examining data sets in order to draw conclusions
# about the information they contain, increasingly with the aid of specialized systems
# and software. Data analytics technologies and techniques are widely used in commercial
# industries to enable organizations to make more-informed business decisions and by
# scientists and researchers to verify or disprove scientific models, theories and
# hypotheses.
# Out:
# Overwriting wordcount/text2.txt

# %%
import glob
import string

#1. Lee los nombres de archivos
filenames = glob.glob('wordcount/*.txt')


#2. Lee el contenido de los archivos
texto = ''
for filename in filenames:
  texto += ' ' + open(filename, 'r').read() #readline es una sola línea y readlines son todas las líneas

texto = ''.join([c for c in texto if c not in ('!', '?', '.', ',')])
texto = texto.lower()
texto = texto.split()

for word in set(texto):  #set es un tipo de estructura de datos donde un dato solo aparece una vez
  print(word, texto.count(word))

print(texto)

# %%
# !cat out.1
# Out:
# linea 1
# linea 2
# linea 3
# linea 4
# linea 5
# linea 6

# %%
# !tac out.1
# Out:
# linea 6
# linea 5
# linea 4
# linea 3
# linea 2
# linea 1

# %%
# NUEVO MEJOR AMIGO: Stack Overflow

# %%
#Manipulando listas y sus datos

# %%
# %%writefile out.1
# Date, Year, CustomerID, Value
# 2013-01-12, 2013, 1, 100
# 2014-05-12, 2014, 1, 100
# 2013-02-25, 2013, 2, 200
# 2013-04-04, 2013, 1, 100
# 2013-06-21, 2013, 2, 200
# 2014-05-18, 2014, 1, 100
# 2014-06-23, 2014, 2, 200
# 2013-02-28, 2013, 1, 100
# 2013-08-02, 2013, 1, 100
# Out:
# Overwriting out.1

# %%
x = open('out.1', 'r').readlines() #me lo convierte en lista
x
# Out:
# ['Date, Year, CustomerID, Value\n',
#  '2013-01-12, 2013, 1, 100\n',
#  '2014-05-12, 2014, 1, 100\n',
#  '2013-02-25, 2013, 2, 200\n',
#  '2013-04-04, 2013, 1, 100\n',
#  '2013-06-21, 2013, 2, 200\n',
#  '2014-05-18, 2014, 1, 100\n',
#  '2014-06-23, 2014, 2, 200\n',
#  '2013-02-28, 2013, 1, 100\n',
#  '2013-08-02, 2013, 1, 100']

# %%
x = [e.replace('\n', '') for e in x]
x
# Out:
# ['Date, Year, CustomerID, Value',
#  '2013-01-12, 2013, 1, 100',
#  '2014-05-12, 2014, 1, 100',
#  '2013-02-25, 2013, 2, 200',
#  '2013-04-04, 2013, 1, 100',
#  '2013-06-21, 2013, 2, 200',
#  '2014-05-18, 2014, 1, 100',
#  '2014-06-23, 2014, 2, 200',
#  '2013-02-28, 2013, 1, 100',
#  '2013-08-02, 2013, 1, 100']

# %%
x = [z.split(',') for z in x]
x
# Out:
# [['Date', ' Year', ' CustomerID', ' Value'],
#  ['2013-01-12', ' 2013', ' 1', ' 100'],
#  ['2014-05-12', ' 2014', ' 1', ' 100'],
#  ['2013-02-25', ' 2013', ' 2', ' 200'],
#  ['2013-04-04', ' 2013', ' 1', ' 100'],
#  ['2013-06-21', ' 2013', ' 2', ' 200'],
#  ['2014-05-18', ' 2014', ' 1', ' 100'],
#  ['2014-06-23', ' 2014', ' 2', ' 200'],
#  ['2013-02-28', ' 2013', ' 1', ' 100'],
#  ['2013-08-02', ' 2013', ' 1', ' 100']]

# %%
[z[0] for z in x[1:]]
# Out:
# ['2013-01-12',
#  '2014-05-12',
#  '2013-02-25',
#  '2013-04-04',
#  '2013-06-21',
#  '2014-05-18',
#  '2014-06-23',
#  '2013-02-28',
#  '2013-08-02']

# %%
[z[0].split('-') for z in x[1:]]
# Out:
# [['2013', '01', '12'],
#  ['2014', '05', '12'],
#  ['2013', '02', '25'],
#  ['2013', '04', '04'],
#  ['2013', '06', '21'],
#  ['2014', '05', '18'],
#  ['2014', '06', '23'],
#  ['2013', '02', '28'],
#  ['2013', '08', '02']]

# %%
[z[0].split('-')[1] for z in x[1:]]
# Out:
# ['01', '05', '02', '04', '06', '05', '06', '02', '08']

# %%
x[1:] = [z + [z[0].split('-')[1]] for z in x[1:]]
x
# Out:
# [['Date', ' Year', ' CustomerID', ' Value'],
#  ['2013-01-12', ' 2013', ' 1', ' 100', '01', '01', '01'],
#  ['2014-05-12', ' 2014', ' 1', ' 100', '05', '05', '05'],
#  ['2013-02-25', ' 2013', ' 2', ' 200', '02', '02', '02'],
#  ['2013-04-04', ' 2013', ' 1', ' 100', '04', '04', '04'],
#  ['2013-06-21', ' 2013', ' 2', ' 200', '06', '06', '06'],
#  ['2014-05-18', ' 2014', ' 1', ' 100', '05', '05', '05'],
#  ['2014-06-23', ' 2014', ' 2', ' 200', '06', '06', '06'],
#  ['2013-02-28', ' 2013', ' 1', ' 100', '02', '02', '02'],
#  ['2013-08-02', ' 2013', ' 1', ' 100', '08', '08', '08']]

# %%
x[0].append('Month')
x
# Out:
# [['Date', ' Year', ' CustomerID', ' Value', 'Month'],
#  ['2013-01-12', ' 2013', ' 1', ' 100', '01', '01', '01'],
#  ['2014-05-12', ' 2014', ' 1', ' 100', '05', '05', '05'],
#  ['2013-02-25', ' 2013', ' 2', ' 200', '02', '02', '02'],
#  ['2013-04-04', ' 2013', ' 1', ' 100', '04', '04', '04'],
#  ['2013-06-21', ' 2013', ' 2', ' 200', '06', '06', '06'],
#  ['2014-05-18', ' 2014', ' 1', ' 100', '05', '05', '05'],
#  ['2014-06-23', ' 2014', ' 2', ' 200', '06', '06', '06'],
#  ['2013-02-28', ' 2013', ' 1', ' 100', '02', '02', '02'],
#  ['2013-08-02', ' 2013', ' 1', ' 100', '08', '08', '08']]

# %%
#También resulta muy simple la aplicación de filtros para seleccionar solo una porción de los datos. Por ejemplo, para obtener únicamente los registros del año 2013:
[z for z in x if z[1] == ' 2013']
# Out:
# [['2013-01-12', ' 2013', ' 1', ' 100', '01', '01', '01'],
#  ['2013-02-25', ' 2013', ' 2', ' 200', '02', '02', '02'],
#  ['2013-04-04', ' 2013', ' 1', ' 100', '04', '04', '04'],
#  ['2013-06-21', ' 2013', ' 2', ' 200', '06', '06', '06'],
#  ['2013-02-28', ' 2013', ' 1', ' 100', '02', '02', '02'],
#  ['2013-08-02', ' 2013', ' 1', ' 100', '08', '08', '08']]

# %%
# Una función que con un Numcol y una lista me pueda cambiar los valores de toda una columa
def aplicarfuncion(x,  numcol, fun):
  result = [z[0:numcol] + [fun(z[numcol])] + z[numcol+1:] for z in x[1:]]
  result = [x[0]] + result
  
  return result

aplicarfuncion(x,2,float)
# Out:
# [['Date', ' Year', ' CustomerID', ' Value', 'Month'],
#  ['2013-01-12', ' 2013', 1.0, ' 100', '01', '01', '01'],
#  ['2014-05-12', ' 2014', 1.0, ' 100', '05', '05', '05'],
#  ['2013-02-25', ' 2013', 2.0, ' 200', '02', '02', '02'],
#  ['2013-04-04', ' 2013', 1.0, ' 100', '04', '04', '04'],
#  ['2013-06-21', ' 2013', 2.0, ' 200', '06', '06', '06'],
#  ['2014-05-18', ' 2014', 1.0, ' 100', '05', '05', '05'],
#  ['2014-06-23', ' 2014', 2.0, ' 200', '06', '06', '06'],
#  ['2013-02-28', ' 2013', 1.0, ' 100', '02', '02', '02'],
#  ['2013-08-02', ' 2013', 1.0, ' 100', '08', '08', '08']]
