# %%
# !pwd
# Out:
# /content

# %%
mkdir practica-bas-1

# %%
mkdir practica-bas-1/1

# %%
mkdir practica-bas-1/2

# %%
mkdir practica-bas-1/3

# %%
pwd
# Out:
# u'/content'

# %%
cd practica-bas-1
# Out:
# /content/practica-bas-1

# %%
pwd
# Out:
# u'/content/practica-bas-1'

# %%
cd 1
# Out:
# /content/practica-bas-1/1

# %%
# mkdir me permite crear una carpeta

# %%
mkdir 1/1-1
# Out:
# mkdir: cannot create directory ‘1/1-1’: No such file or directory

# %%
# cd me permite cambiar el directorio actual sobre el que estoy trabajando

# %%
cd practica-bas-1
# Out:
# [Errno 2] No such file or directory: 'practica-bas-1'
# /content/practica-bas-1/1

# %%
# Me indica el directorio actual sobre el que estoy trabajando

# %%
pwd
# Out:
# u'/content/practica-bas-1/1'

# %%
#El punto hace referencia a mi carpeta actual y me ahorra copiar toda la dirección

# %%
mkdir ./1-1

# %%
#Puedo poner un espacio entre las dos carpetas que voy a crear.

# %%
mkdir ./1-2 1-3

# %%
pwd
# Out:
# u'/content/practica-bas-1/1'

# %%
cd /content/practica-bas-1/2
# Out:
# /content/practica-bas-1/2

# %%
mkdir ./2-1 2-2 2-3

# %%
pwd
# Out:
# u'/content/practica-bas-1/2'

# %%
cd /content/practica-bas-1/3
# Out:
# /content/practica-bas-1/3

# %%
mkdir ./3-1 3-2 3-3

# %%
cd /content/practica-bas-1
# Out:
# /content/practica-bas-1

# %%
#Me permite visualizar el arbol de subdirectorios (en esta versión no lo permite)

# %%
tree

# %%
cd ./1/1-1
# Out:
# /content/practica-bas-1/1/1-1

# %%
touch ./SUCCESS.txt

# %%
#Instalar un comando

# %%
# !apt-get install tree
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tree is already the newest version (1.7.0-5).
# 0 upgraded, 0 newly installed, 0 to remove and 8 not upgraded.

# %%
#Tree para visualizar un arbol de subdirectorios

# %%
# !tree
# Out:
# .
# ├── 1
# │   ├── 1-1
# │   ├── 1-2
# │   └── 1-3
# ├── 2
# │   ├── 2-1
# │   ├── 2-2
# │   └── 2-3
# └── 3
#     ├── 3-1
#     ├── 3-2
#     └── 3-3
#
# 12 directories, 0 files

# %%
cd ./1/1-1/
# Out:
# /content/practica-bas-1/1/1-1

# %%
# touch me permite crear un archivo en un directorio

# %%
# !touch ./SUCCESS.txt part-0.txt

# %%
#cp me permite copiar archivos

# %%
cp part-0.txt part-1.txt

# %%
cp part-0.txt part-2.txt

# %%
#mv para renombrar archivos

# %%
# !mv part-0.txt part-0001.txt

# %%
# !mv part-1.txt part-00001.txt

# %%
cd /content/practica-bas-1
# Out:
# /content/practica-bas-1

# %%
# !tree
# Out:
# .
# ├── 1
# │   ├── 1-1
# │   │   ├── part-00001.txt
# │   │   ├── part-0001.txt
# │   │   ├── part-2.txt
# │   │   └── SUCCESS.txt
# │   ├── 1-2
# │   └── 1-3
# ├── 2
# │   ├── 2-1
# │   ├── 2-2
# │   └── 2-3
# └── 3
#     ├── 3-1
#     ├── 3-2
#     └── 3-3
#
# 12 directories, 4 files

# %%
#mv también me permite mover el contenido de una carpeta de <origen> a una <destino>

# %%
mv ./1/1-1/ ./3/3-3/

# %%
#rmdir para eliminar directorios

# %%
# !rmdir ./1/1-3/

# %%
#rm para borrar archivos

# %%
# !rm ./3/3-3/1-1/SUCCESS*

# %%
#Para devolverme un carpeta en el directorio agrego uno o más puntos de acuerdo a lo que me quiera devolver

# %%
cd ./2/2-2/
# Out:
# /content/practica-bas-1/2/2-2

# %%
cd ../
# Out:
# /content/practica-bas-1/2

# %%
cd ../
# Out:
# /content/practica-bas-1
